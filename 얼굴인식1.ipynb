# %% [markdown]
# <a href="https://colab.research.google.com/github/PI-hamin/open-cv-activity/blob/main/%EC%96%BC%EA%B5%B4%EC%9D%B8%EC%8B%9D1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 사진에서 사람의 얼굴을 검출하는 code 를 공부한다. 
# 참고 : https://minimin2.tistory.com/139

# %%
# Haar cascade 특징 : face 가 아니면 버려버려 연산량이 줄어듬.

# %%
# numpy 와 matplotlib 를 사용하기위해 import 
import cv2
import numpy as np # numpy 를 import 하고 np라는 이름으로 패키지를 참조
import matplotlib
#import 시 error가 없으면 정상으로 설치된것임.

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-5c24022b-edb2-44e7-9238-d838bc2a148e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c24022b-edb2-44e7-9238-d838bc2a148e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving itzy.jpg to itzy.jpg

# %%
image = 'itzy.jpg'

# %%
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread(image, cv2.IMREAD_COLOR)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F5AEDF8D790>

# %%
# haarcascade 를 read 하는 과정

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# %%
#얼굴을 찾는 과정

# %%
faces = face_cascade.detectMultiScale(img,1.3,5)
for (x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

# %%
# 눈 찾기

# %%
roi_color = img[y:y + h, x:x + w]
roi_gray = img[y:y + h, x:x + w]
eyes = eye_cascade.detectMultiScale(roi_gray)
for (ex, ey, ew, eh) in eyes:
  cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F5AECE26690>

# %%
# 결과 : 5명의 인물중 4명의 얼굴을 찾아내었고 1명의 눈을 찾아냈다.
